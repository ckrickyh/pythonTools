# %% [markdown]
# <a href="https://colab.research.google.com/github/ckrickyh/pythonTools/blob/main/airTableF1_uploadPhotos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyairtable
# !apt-get install -qq xattr
# Out:
# Requirement already satisfied: pyairtable in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: inflection in /usr/local/lib/python3.12/dist-packages (from pyairtable) (0.5.1)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from pyairtable) (2.11.7)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from pyairtable) (2.32.4)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pyairtable) (4.15.0)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.12/dist-packages (from pyairtable) (2.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->pyairtable) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->pyairtable) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->pyairtable) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22.0->pyairtable) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22.0->pyairtable) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22.0->pyairtable) (2025.8.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/pyConfig')
from airtableconfig import tokenConfig, tableNameConfig

# %% [markdown]
# # Setting

# %%
# google folder

project = 'airTable'
fld = 'airTablePhotoUpload'
drive_path = f'/content/drive/MyDrive/Muni/{project}/{fld}'

# %%
token = tokenConfig
baseId = 'apppoiK7vk3IVc6g1'
tableName = tableNameConfig

'''
baseId = 'apphtjuFujdfd647NaV7'
tableName = 'tblOhXdfdqpaDbX5LeKR'
# https://airtable.com/apphtjuFujdfd647NaV7/tblOhXdfdqpaDbX5LeKR/viw62XcVen1JVp2a7?blocks=hide
'''
# Out:
# "\nbaseId = 'apphtjuFujdfd647NaV7'\ntableName = 'tblOhXdfdqpaDbX5LeKR'\n# https://airtable.com/apphtjuFujdfd647NaV7/tblOhXdfdqpaDbX5LeKR/viw62XcVen1JVp2a7?blocks=hide\n"

# %%
from pyairtable import Api
import requests
import os
import pandas as pd
#from google.colab import drive
from pathlib import Path
import time
from PIL import Image
from io import BytesIO
#google
#drive.mount('/content/drive')

# %% [markdown]
# # Retrieve google photo url

# %%
from subprocess import getoutput
from IPython.display import HTML

# %%
#注意路徑名
# %cd /content/gdrive/MyDrive/ToHyd/SWTCoverPhoto/
os.chdir(drive_path)

import pathlib
import pandas as pd

#df1=pd.DataFrame(columns = ["Path", "ShareLink"])

def get_shareable_link(file_path):
    fid = getoutput("xattr -p 'user.drive.id' " + "'" + file_path + "'")
    print(fid)
    # make a link and display it
    glink = HTML(f"<a href=https://drive.google.com/file/d/{fid} target=_blank>file URL</a>")
    return glink, fid


#files = !ls /content/gdrive/MyDrive/ImageAI/*.jpg
#for file_path in files:
    #print(file_path)

#注意路徑名
path = pathlib.Path(drive_path)


file_paths = []
links = []
fids = []
fileNames = []
fileFullNames = []
treeNos = []
for files in path.glob("**/*.*"):

  ###for files in path.glob("**/*.jpg"):        #all subfolder with .jpg
  print(files)

  #===================================== ### 檔案類型
  fileType = [".JPG", ".JPEG", ".PNG"]

  if str(files).upper().endswith(tuple(fileType)):

    file_path = str(files)   #for document
    print(file_path)
    # file_path = str(files.parent.absolute())    #for folder, taken by parent folder method

    glink, fid = get_shareable_link(file_path)

    link = 'https://drive.google.com/file/d/'+ getoutput("xattr -p 'user.drive.id' " + "'" + file_path + "'")   #for document
    # link = 'https://drive.google.com/drive/folders/'+ getoutput("xattr -p 'user.drive.id' " + "'" + file_path + "'")   #for folder

    fileNames.append(Path(files).stem)
    fileFullNames.append(Path(files).name)
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T017__Whole View.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T017__Whole View.JPG
# 1hLyrErBLSiWj7_ZcYIBJL1i7S3S_TPSk
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T014__Whole View.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T014__Whole View.JPG
# 1DhrCA5q3srz6twqXyX10QNqpbrcCTlFR
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T017_Dead branch.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T017_Dead branch.JPG
# 1SggvXqRR6zgFq6BFn2AAeOFKQQCyaiY7
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T013__Whole View.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T013__Whole View.JPG
# 1KQj4H1qyQNQD2L9oX6LvIzK8Mj78HDtK
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T018__Whole ViewRemoved.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T018__Whole ViewRemoved.JPG
# 1pCCKxDzoZKpWb3itv1iVAEYNbaUFe3Jf
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T020__Whole View.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T020__Whole View.JPG
# 1S_jb7ZbZKZiKsYWcVlg_-c4UTAjOo0WP
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T021_Dead branch.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/Copy of T021_Dead branch.JPG
# 1yx7mve0xtRSYJE7-fgOTiwVDp8PJbVON
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T005_Overgrown branches (2).JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T005_Overgrown branches (2).JPG
# 1H_dBpnDV1bP1x_KqmIpGCJXN6qEn5VaE
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T001__Whole View.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T001__Whole View.JPG
# 1as63AOQxO5p2bDIKla5qWE98s5Y7utd_
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T005_Overgrown branches (3).JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T005_Overgrown branches (3).JPG
# 1oiIaa_iiM0QxArfIE_yOHxzZ35wEO1AR
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T001_Dead fronds.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T001_Dead fronds.JPG
# 1oA_-oBv3_QPaU0-xOQiMfOl20rGOcdDC
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T002__Whole View.JPG
# /content/drive/MyDrive/Muni/airTable/airTablePhotoUpload/T002__Whole View.JPG
# 1YZdbhwKCBYmQORmvGigKnwXj1KDz9EqI
#                                      fileName  \
# 0         Screenshot 2025-08-28 at 1.46.11 PM
# 1                                 T083_defect
# 2                                 T083_wshole
# 3                    Copy of T005__Whole View
# 4                    Copy of T003__Whole View
# 5         Copy of T005_Overgrown branches (1)
# 6                    Copy of T004__Whole View
# 7                    Copy of T004_Dead fronds
# 8   Copy of T005_CrownConflictingWithLampPost
# 9         Copy of T005_Overgrown branches (3)
# 10                   Copy of T006__Whole View
# 11                   Copy of T007__Whole View
# 12                   Copy of T008__Whole View
# 13                   Copy of T008_Dead branch
# 14               Copy of T008_Soil compaction
# 15                   Copy of T009__Whole View
# 16                   Copy of T009_Dead branch
# 17                   Copy of T010__Whole View
# 18                   Copy of T011__Whole View
# 19                   Copy of T012__Whole View
# 20                   Copy of T021__Whole View
# 21                   Copy of T020_Dead branch
# 22           Copy of T017_Abnormal bark crack
# 23                   Copy of T017__Whole View
# 24                   Copy of T014__Whole View
# 25                   Copy of T017_Dead branch
# 26                   Copy of T013__Whole View
# 27            Copy of T018__Whole ViewRemoved
# 28                   Copy of T020__Whole View
# 29                   Copy of T021_Dead branch
# 30                T005_Overgrown branches (2)
# 31                           T001__Whole View
# 32                T005_Overgrown branches (3)
# 33                           T001_Dead fronds
# 34                           T002__Whole View
#
#                                      fileFullName  \
# 0         Screenshot 2025-08-28 at 1.46.11 PM.png
# 1                                 T083_defect.png
# 2                                 T083_wshole.png
# 3                    Copy of T005__Whole View.JPG
# 4                    Copy of T003__Whole View.JPG
# 5         Copy of T005_Overgrown branches (1).JPG
# 6                    Copy of T004__Whole View.JPG
# 7                    Copy of T004_Dead fronds.JPG
# 8   Copy of T005_CrownConflictingWithLampPost.JPG
# 9         Copy of T005_Overgrown branches (3).JPG
# 10                   Copy of T006__Whole View.JPG
# 11                   Copy of T007__Whole View.JPG
# 12                   Copy of T008__Whole View.JPG
# 13                   Copy of T008_Dead branch.JPG
# 14               Copy of T008_Soil compaction.JPG
# 15                   Copy of T009__Whole View.JPG
# 16                   Copy of T009_Dead branch.JPG
# 17                   Copy of T010__Whole View.JPG
# 18                   Copy of T011__Whole View.JPG
# 19                   Copy of T012__Whole View.JPG
# 20                   Copy of T021__Whole View.JPG
# 21                   Copy of T020_Dead branch.JPG
# 22           Copy of T017_Abnormal bark crack.JPG
# 23                   Copy of T017__Whole View.JPG
# 24                   Copy of T014__Whole View.JPG
# 25                   Copy of T017_Dead branch.JPG
# 26                   Copy of T013__Whole View.JPG
# 27            Copy of T018__Whole ViewRemoved.JPG
# 28                   Copy of T020__Whole View.JPG
# 29                   Copy of T021_Dead branch.JPG
# 30                T005_Overgrown branches (2).JPG
# 31                           T001__Whole View.JPG
# 32                T005_Overgrown branches (3).JPG
# 33                           T001_Dead fronds.JPG
# 34                           T002__Whole View.JPG
#
#                                  treeNo  \
# 0   Screenshot 2025-08-28 at 1.46.11 PM
# 1                                  T083
# 2                                  T083
# 3                                  T005
# 4                                  T003
# 5                                  T005
# 6                                  T004
# 7                                  T004
# 8                                  T005
# 9                                  T005
# 10                                 T006
# 11                                 T007
# 12                                 T008
# 13                                 T008
# 14                                 T008
# 15                                 T009
# 16                                 T009
# 17                                 T010
# 18                                 T011
# 19                                 T012
# 20                                 T021
# 21                                 T020
# 22                                 T017
# 23                                 T017
# 24                                 T014
# 25                                 T017
# 26                                 T013
# 27                                 T018
# 28                                 T020
# 29                                 T021
# 30                                 T005
# 31                                 T001
# 32                                 T005
# 33                                 T001
# 34                                 T002
#
#                                                  Path  \
# 0   /content/drive/MyDrive/Muni/airTable/airTableP...
# 1   /content/drive/MyDrive/Muni/airTable/airTableP...
# 2   /content/drive/MyDrive/Muni/airTable/airTableP...
# 3   /content/drive/MyDrive/Muni/airTable/airTableP...
# 4   /content/drive/MyDrive/Muni/airTable/airTableP...
# 5   /content/drive/MyDrive/Muni/airTable/airTableP...
# 6   /content/drive/MyDrive/Muni/airTable/airTableP...
# 7   /content/drive/MyDrive/Muni/airTable/airTableP...
# 8   /content/drive/MyDrive/Muni/airTable/airTableP...
# 9   /content/drive/MyDrive/Muni/airTable/airTableP...
# 10  /content/drive/MyDrive/Muni/airTable/airTableP...
# 11  /content/drive/MyDrive/Muni/airTable/airTableP...
# 12  /content/drive/MyDrive/Muni/airTable/airTableP...
# 13  /content/drive/MyDrive/Muni/airTable/airTableP...
# 14  /content/drive/MyDrive/Muni/airTable/airTableP...
# 15  /content/drive/MyDrive/Muni/airTable/airTableP...
# 16  /content/drive/MyDrive/Muni/airTable/airTableP...
# 17  /content/drive/MyDrive/Muni/airTable/airTableP...
# 18  /content/drive/MyDrive/Muni/airTable/airTableP...
# 19  /content/drive/MyDrive/Muni/airTable/airTableP...
# 20  /content/drive/MyDrive/Muni/airTable/airTableP...
# 21  /content/drive/MyDrive/Muni/airTable/airTableP...
# 22  /content/drive/MyDrive/Muni/airTable/airTableP...
# 23  /content/drive/MyDrive/Muni/airTable/airTableP...
# 24  /content/drive/MyDrive/Muni/airTable/airTableP...
# 25  /content/drive/MyDrive/Muni/airTable/airTableP...
# 26  /content/drive/MyDrive/Muni/airTable/airTableP...
# 27  /content/drive/MyDrive/Muni/airTable/airTableP...
# 28  /content/drive/MyDrive/Muni/airTable/airTableP...
# 29  /content/drive/MyDrive/Muni/airTable/airTableP...
# 30  /content/drive/MyDrive/Muni/airTable/airTableP...
# 31  /content/drive/MyDrive/Muni/airTable/airTableP...
# 32  /content/drive/MyDrive/Muni/airTable/airTableP...
# 33  /content/drive/MyDrive/Muni/airTable/airTableP...
# 34  /content/drive/MyDrive/Muni/airTable/airTableP...
#
#                                             ShareLink  \
# 0   https://drive.google.com/file/d/1a3xxks07Hi2Dy...
# 1   https://drive.google.com/file/d/1F5gyB7uAaf8kd...
# 2   https://drive.google.com/file/d/1ddcg2WZSAugVx...
# 3   https://drive.google.com/file/d/12lgVNYycdd3aA...
# 4   https://drive.google.com/file/d/1J6EvL3iK0QFJO...
# 5   https://drive.google.com/file/d/1dRuRqL7ohbFtu...
# 6   https://drive.google.com/file/d/1pdSr8NgalAawn...
# 7   https://drive.google.com/file/d/1E2lMsgYyit0JA...
# 8   https://drive.google.com/file/d/1Y9ajGsVI3a7XX...
# 9   https://drive.google.com/file/d/11iwknIvZeEcD6...
# 10  https://drive.google.com/file/d/10qTmfBXntAMCf...
# 11  https://drive.google.com/file/d/1qhaM6_ZOA6DUD...
# 12  https://drive.google.com/file/d/1l5kJH35qaUWCD...
# 13  https://drive.google.com/file/d/10kygHBC5E4fcc...
# 14  https://drive.google.com/file/d/1rjWO-oEQdqm_u...
# 15  https://drive.google.com/file/d/1KFz2lUJEr8mEa...
# 16  https://drive.google.com/file/d/1-5g8WeyOdAHsv...
# 17  https://drive.google.com/file/d/1SDXZwOtgRBo7w...
# 18  https://drive.google.com/file/d/1QfMeJS4E0Ii-j...
# 19  https://drive.google.com/file/d/1pbzS4SHm0f6H6...
# 20  https://drive.google.com/file/d/18-8Yj7DLL8tf8...
# 21  https://drive.google.com/file/d/1760mPYTgZ1zm7...
# 22  https://drive.google.com/file/d/1iGL2iUDbiJsiS...
# 23  https://drive.google.com/file/d/1hLyrErBLSiWj7...
# 24  https://drive.google.com/file/d/1DhrCA5q3srz6t...
# 25  https://drive.google.com/file/d/1SggvXqRR6zgFq...
# 26  https://drive.google.com/file/d/1KQj4H1qyQNQD2...
# 27  https://drive.google.com/file/d/1pCCKxDzoZKpWb...
# 28  https://drive.google.com/file/d/1S_jb7ZbZKZiKs...
# %% [markdown]
# # upload photos to airTable's attachment field

# %%
def uploadFiles(TreeNo, driveFid, fileFullName):

  #if record['fields']['Tree No.'] == TreeNo:
  print(f'TreeNo: {TreeNo}')
  RECORD_ID = record['id']
  print(f'AirTable RECORD_ID: {RECORD_ID}') #reczx1Jy8hNHkjJ7r

  # not work
  # IMAGE_URL = 'https://drive.google.com/file/d/1ddcg2WZSAugVxycnjpLXCXnCG1G8pGje/view?usp=drive_link'

  # Convert Google Drive link to direct download link
  #drive_file_id = '1ddcg2WZSAugVxycnjpLXCXnCG1G8pGje'  # Extracted from your original link
  IMAGE_URL = f'https://drive.google.com/uc?id={driveFid}'

  r = requests.get(IMAGE_URL)
  if r.status_code == 200:
    # Save the image to a temporary file
    fileName = f'/content/{fileFullName}'

    with open(fileName, 'wb') as f:
        f.write(r.content)

    try:
      updated_record = table.upload_attachment(
          record_id = RECORD_ID,
          field = 'rawPhoto',  #import field 對應 airtable rawPhoto field
          filename = fileName #os.path.join('/content',fileFullName)
          # filename = IMAGE_URL
        )
    except Exception as e:
      print(f"Error uploading photo: {e}")

# %%
api = Api(token)
table = api.table(baseId,tableName)
records = table.all()

from pyairtable import Table

# Replace with your API key, base ID, and table name
#API_KEY = token
#BASE_ID = baseId
#TABLE_NAME = tableName

errorLst = []



#============
for x, record in enumerate(records):
  # record: {'id': 'reczx1Jy8hNHkjJ7r', 'createdTime': '2025-08-28T07:55:27.000Z', 'fields': {'Tree No.': 'T083', 'Scientific Name': 'Lagerstroemia indica', 'Chinese Name': '紫薇', 'DBH (mm)': 188, 'Height (m)': 4, 'Crown Spread\n (m)': 5, 'Tree Form\n (Good/\n Fair/\n Poor)': 'Fair', 'Tree Health\n (Good/\n Fair/\n Poor)': 'Fair', 'Remark on Crown': ['Epicormics'], 'Remark on Trunk': ['Included bark', 'Multi-trunks'], 'loc': 'Baycrest', 'triage': 'null', 'gp': '1'}}
  if 'Tree No.' in record['fields'].keys():

    tree_no = record['fields']['Tree No.']
    #print(f'record of tree_no: {tree_no}')

    if tree_no in dfLink['treeNo'].values: #values as a ndarray, faster than .tolist()
      print(f'record: {tree_no} in dfLink')

      # find the indexs in dfLink
      indices = dfLink.index[dfLink['treeNo'] == tree_no].tolist()
      print(f'indice: {indices}')

      for i in indices:
        uploadFiles(dfLink['treeNo'][i], dfLink['fid'][i], dfLink['fileFullName'][i])
        print(f'upload: {dfLink['fid'][i]}')
        print("===================")
  else:
    errorLst.append(x)
if len(errorLst)>0 :
  errorMsg = f'{len(errorLst)} files cannot upload'
else:
  errorMsg = ''
print(f'done. {errorMsg}')
# Out:
# record: T010 in dfLink
# indice: [17]
# TreeNo: T010
# AirTable RECORD_ID: rec0MceU2OiigRO7q
# upload: 1SDXZwOtgRBo7wgufRuTs02WwBb3_BSuY
# ===================
# record: T011 in dfLink
# indice: [18]
# TreeNo: T011
# AirTable RECORD_ID: rec1yhZDa0f46yCHX
# upload: 1QfMeJS4E0Ii-jt8Zc5kNpL4IvUbiMSmh
# ===================
# record: T002 in dfLink
# indice: [34]
# TreeNo: T002
# AirTable RECORD_ID: rec4sJPEx6Dp6qDwW
# upload: 1YZdbhwKCBYmQORmvGigKnwXj1KDz9EqI
# ===================
# record: T008 in dfLink
# indice: [12, 13, 14]
# TreeNo: T008
# AirTable RECORD_ID: rec5OD8NCAXL2H4L5
# upload: 1l5kJH35qaUWCDpTyX_j-mapDWxdhhk8B
# ===================
# TreeNo: T008
# AirTable RECORD_ID: rec5OD8NCAXL2H4L5
# upload: 10kygHBC5E4fcccgJsan6QqXVp0NAZrfl
# ===================
# TreeNo: T008
# AirTable RECORD_ID: rec5OD8NCAXL2H4L5
# upload: 1rjWO-oEQdqm_udVRCWahIm4gP5kogA8_
# ===================
# record: T018 in dfLink
# indice: [27]
# TreeNo: T018
# AirTable RECORD_ID: recBG2bWt74BfjVkM
# upload: 1pCCKxDzoZKpWb3itv1iVAEYNbaUFe3Jf
# ===================
# record: T001 in dfLink
# indice: [31, 33]
# TreeNo: T001
# AirTable RECORD_ID: recIhCGkY63HSUGcG
# upload: 1as63AOQxO5p2bDIKla5qWE98s5Y7utd_
# ===================
# TreeNo: T001
# AirTable RECORD_ID: recIhCGkY63HSUGcG
# upload: 1oA_-oBv3_QPaU0-xOQiMfOl20rGOcdDC
# ===================
# record: T009 in dfLink
# indice: [15, 16]
# TreeNo: T009
# AirTable RECORD_ID: recLWMyTWscwcTbOs
# upload: 1KFz2lUJEr8mEa4ZyEGFNSAX5UQCYiUU8
# ===================
# TreeNo: T009
# AirTable RECORD_ID: recLWMyTWscwcTbOs
# upload: 1-5g8WeyOdAHsvAmwSPgy8Vcj3AgRtDtF
# ===================
# record: T007 in dfLink
# indice: [11]
# TreeNo: T007
# AirTable RECORD_ID: recS7WEsX6Rkpp80t
# upload: 1qhaM6_ZOA6DUDmCsqWTHVEZzbb6tA0-E
# ===================
# record: T017 in dfLink
# indice: [22, 23, 25]
# TreeNo: T017
# AirTable RECORD_ID: recX5tGPP7FNOyAn1
# upload: 1iGL2iUDbiJsiSOwtG-SS0rPeDReYFlqC
# ===================
# TreeNo: T017
# AirTable RECORD_ID: recX5tGPP7FNOyAn1
# upload: 1hLyrErBLSiWj7_ZcYIBJL1i7S3S_TPSk
# ===================
# TreeNo: T017
# AirTable RECORD_ID: recX5tGPP7FNOyAn1
# upload: 1SggvXqRR6zgFq6BFn2AAeOFKQQCyaiY7
# ===================
# record: T006 in dfLink
# indice: [10]
# TreeNo: T006
# AirTable RECORD_ID: recYqW9683k6ZQ02A
# upload: 10qTmfBXntAMCfm-i5mgWr3FyE_CAu1Lr
# ===================
# record: T020 in dfLink
# indice: [21, 28]
# TreeNo: T020
# AirTable RECORD_ID: recb4hoJ3b4enRSEI
# upload: 1760mPYTgZ1zm7WQUXKrU9pgrN1R2Aq57
# ===================
# TreeNo: T020
# AirTable RECORD_ID: recb4hoJ3b4enRSEI
# upload: 1S_jb7ZbZKZiKsYWcVlg_-c4UTAjOo0WP
# ===================
# record: T021 in dfLink
# indice: [20, 29]
# TreeNo: T021
# AirTable RECORD_ID: recbyjpHb8WrDEwAQ
# upload: 18-8Yj7DLL8tf8X2gIc8cW7OUZX02BBAi
# ===================
# TreeNo: T021
# AirTable RECORD_ID: recbyjpHb8WrDEwAQ
# upload: 1yx7mve0xtRSYJE7-fgOTiwVDp8PJbVON
# ===================
# record: T003 in dfLink
# indice: [4]
# TreeNo: T003
# AirTable RECORD_ID: recg77m3woAre75pC
# upload: 1J6EvL3iK0QFJOgCH8wQV_kf7HQXO2kZ0
# ===================
# record: T012 in dfLink
# indice: [19]
# TreeNo: T012
# AirTable RECORD_ID: rech2D6HjlxnqHtPi
# upload: 1pbzS4SHm0f6H6_6hD3M8MTr-qxNvbrx2
# ===================
# record: T004 in dfLink
# indice: [6, 7]
# TreeNo: T004
# AirTable RECORD_ID: reciO2b3RVnCrkuOM
# upload: 1pdSr8NgalAawnqsk1nPhZEQgDSHV-V94
# ===================
# TreeNo: T004
# AirTable RECORD_ID: reciO2b3RVnCrkuOM
# upload: 1E2lMsgYyit0JAYuiSKQtPTFPLkoR34Wl
# ===================
# record: T013 in dfLink
# indice: [26]
# TreeNo: T013
# AirTable RECORD_ID: reclE1STioHpbeJpf
# upload: 1KQj4H1qyQNQD2L9oX6LvIzK8Mj78HDtK
# ===================
# record: T014 in dfLink
# indice: [24]
# TreeNo: T014
# AirTable RECORD_ID: recvA1kCMCpsaw0ZC
# upload: 1DhrCA5q3srz6twqXyX10QNqpbrcCTlFR
# ===================
# record: T005 in dfLink
# indice: [3, 5, 8, 9, 30, 32]
# TreeNo: T005
# AirTable RECORD_ID: recxlYv2E9EHeczVN
# upload: 12lgVNYycdd3aANshtgbF9YbIOFGb8fd_
# ===================
# TreeNo: T005
# AirTable RECORD_ID: recxlYv2E9EHeczVN
# upload: 1dRuRqL7ohbFtuvC5U0akG8YLHJO9IMlB
# ===================
# TreeNo: T005
# AirTable RECORD_ID: recxlYv2E9EHeczVN
# upload: 1Y9ajGsVI3a7XXwisBocRgfGLee4eVpHd
# ===================
# TreeNo: T005
# AirTable RECORD_ID: recxlYv2E9EHeczVN
# upload: 11iwknIvZeEcD65D_N-vzsnQXkxETsVuA
# ===================
# TreeNo: T005
# AirTable RECORD_ID: recxlYv2E9EHeczVN
# upload: 1H_dBpnDV1bP1x_KqmIpGCJXN6qEn5VaE
# ===================
# TreeNo: T005
# AirTable RECORD_ID: recxlYv2E9EHeczVN
# upload: 1oiIaa_iiM0QxArfIE_yOHxzZ35wEO1AR
# ===================
# record: T083 in dfLink
# indice: [1, 2]
# TreeNo: T083
# AirTable RECORD_ID: reczx1Jy8hNHkjJ7r
# upload: 1F5gyB7uAaf8kdNW4qMCJB_ntXF2H5rLA
# ===================
# TreeNo: T083
# AirTable RECORD_ID: reczx1Jy8hNHkjJ7r
# upload: 1ddcg2WZSAugVxycnjpLXCXnCG1G8pGje
# ===================
# done.
